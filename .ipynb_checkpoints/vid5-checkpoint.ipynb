# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import PillowWriter
import numba
from numba import jit

# %% [markdown]
# The wave equation (with damping and stress-strain coupling):
#
# $$\frac{\partial^2 y}{\partial x^2} - \fr $$

# %%
@numba.jit("f8[:,:](f8[:,:], i8, i8, f8, f8, f8, f8)", nopython=True, nogil=True)
def compute_d(d, times, length, dt, dx, l, gamma):
    length = len(d[0])
    for t in range(1, times-1):
        for i in range(2, length-2):
            outer_fact = (1/(c**2 * dt**2) + gamma/(2*dt))**(-1)
            p1 = 1/dx**2 * (d[t][i-1] - 2*d[t][i] + d[t][i+1])
            p2 = 1/(c**2 * dt**2) * (d[t-1][i] - 2*d[t][i])
            p3 = gamma/(2*dt) * d[t-1][i]
            p4 = l**2 / dx**4 * (d[t][i+2] - 4*d[t][i+1] + 6*d[t][i] - 4*d[t][i-1] + d[t][i-2])
            d[t+1][i] = outer_fact * (p1 - p2 + p3 - p4)
    return d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3c03d97b42ad> in <module>
# ----> 1 @numba.jit("f8[:,:](f8[:,:], i8, i8, f8, f8, f8, f8)", nopython=True, nogil=True)
#       2 def compute_d(d, times, length, dt, dx, l, gamma):
#       3     length = len(d[0])
#       4     for t in range(1, times-1):
#       5         for i in range(2, length-2):
#
# NameError: name 'numba' is not defined

# %% [markdown]
# $ f^{(4)}(x)\approx\dfrac{f(x+2h)-4f(x+h)+6f(x)-4f(x-h)+f(x-2h)}{h^4}$

# %% [markdown]
# $c / (\Delta x / \Delta t) = 1/2$

# %% [markdown]
# Guitar string length = $0.7~$m
#
# Choose 100 guitar string positions $\implies$ $\Delta x = 0.7~$mm
#
# $c = 405~$m/s so $\Delta t = \Delta x / (2 c) = 1.73 \times 10^{-6} s$

# %%
Nx = 100
Nt = 500000
L = 0.7
dx = L/Nx
c = 405
dt = 5e-6
f = c / (dx/dt)
l = 2e-6
gamma = 2.6e-5

# %%
(1/(c**2 * dt**2) + gamma/(2*dt))**(-1)
# Out:
# 4.1005812811401e-06

# %%
sol = np.zeros((Nt, Nx))

# %%
x0 = np.linspace(0, 0.01, 70)
x1 = np.linspace(0.01, 0, 30)
x = np.concatenate([x0, x1])

# %%
sol[0] = x
sol[1] = x

# %%
sol = compute_d(sol, Nt, Nx, dt, dx, l, gamma)

# %%
plt.plot(sol[500])
plt.plot(sol[20000])

# %%
def animate(i):
    ax.clear()
    ax.plot(sol[i*10])
    ax.set_ylim(-0.01, 0.01)
    
fig, ax = plt.subplots(1,1)
ax.set_ylim(-0.01, 0.01)
ani = animation.FuncAnimation(fig, animate, frames=500, interval=50)
ani.save('string.gif',writer='pillow',fps=20)

# %%
def get_integral(n):
    sin_arr = np.sin(n*np.pi*np.linspace(0, 1, 100))
    return np.array([sum(sin_arr*s) for s in sol])

# %%
fts = [get_integral(n) for n in range(10)]

# %%
tot = sum(fts)[::10]
tot = tot.astype(np.float32)

# %%
from scipy.io import wavfile
from IPython.display import Audio

# %%
wavfile.write('output/v3_a.wav',20000,tot)

# %%
Audio('output/v3_a.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
