# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation

# %% [markdown]
# # Theory

# %% [markdown]
# For a vibrating 2D plate, let the height at some point on the plate during vibration be $u(x,y,t)$. The differential equation governing the motion is given by
#
# $$u_{tt} = c^2\nabla^2 u$$
#
#  where $c$ is the wave speed. The *eigenmodes* of vibration occur when the plate is vibrated at very specific frequencies:
#
# $$f(n,m) = \frac{c}{2\pi} \sqrt{\frac{n^2}{L_x^2} + \frac{m^2}{L_y^2}}$$
#
# where $L_x$ and $L_y$ are the dimensions of the rectangular plate and $n$ and $m$ are integers. In particular, if one knows $c$, $L_x$, and $L_y$, one can plug in different integer values of $n$ and $m$ to determine precisely what these special frequencies are.
#
#  At these special frequencies, we have that $u(x,y,t) = U(x,y)G(t)$ (the solution in space and time is seperable) where $G(t)$ is a periodic oscillating function. If the plate is suspended in the center, then the boundary conditions are such that maximum amplitude occurs at the boundary of the plates, and
#
# $$U(x,y) \propto |\sin(n \pi x/L_x)\sin(m \pi y/L_y) - \sin(m \pi x/L_x)\sin(n \pi y/L_y)|$$
#
# where $n$ and $m$ are **odd** integers corresponding to a particular driving frequency that gives a particular mode of vibration.

# %% [markdown]
# # Coding

# %% [markdown]
# Lets create the coordinates of the rectangular grid

# %%
x = y = np.linspace(-1, 1, 1000)
xv, yv = np.meshgrid(x,y)

# %% [markdown]
# Define a function the represents the amplitude $U(x,y)$

# %%
def amplitude(xv, yv, n, m): 
    return np.abs(np.sin(n*np.pi*xv/2)*np.sin(m*np.pi*yv/2)-np.sin(m*np.pi*xv/2)*np.sin(n*np.pi*yv/2))

# %% [markdown]
# Plot some sample $U(x,y)$ for different values of $n$ and $m$

# %%
plt.pcolormesh(xv, yv, amplitude(xv, yv, 5, 7))
plt.colorbar()

# %% [markdown]
# We can create the coordinates of grains of sand as follows:

# %%
p = np.random.uniform(-1, 1, size=(2,1000))

# %%
p
# Out:
# array([[-0.4019911 , -0.1837229 ,  0.35924108, ..., -0.4677502 ,
#         -0.95942965,  0.61222099],
#        [ 0.68550182, -0.53674609,  0.49167578, ...,  0.58557462,
#         -0.80746597, -0.31159591]])

# %% [markdown]
# We can then plot them on the grid:

# %%
p.shape
# Out:
# (2, 1000)

# %%
plt.scatter(*p)

# %% [markdown]
# This `Sand` class will include
# 1. The number of points `N_points`
# 2. The locations of the points `points`
# 3. The distance `delta` a grain of sand moves when at a position of maximum vibrating amplitude
# 4. A function `move`, which will move all the sand grains at once. Each grain moves in random direction specified by `angle`
#
# In addition, the previous locations of the points `prev_points` will be tracked so that smooth animations can be produced later (can plot intermediate locations through interpolation)

# %%
class Sand:
    def __init__(self, N_points, amplitude, delta=0.05):
        self.N_points = N_points
        self.points = np.random.uniform(-1, 1, size=(2,self.N_points))
        self.amplitude = amplitude
        self.delta = delta
    def move(self, **amplitude_params):
        angles = np.random.uniform(0, 2*np.pi, size=self.N_points)
        dr = self.delta * np.array([np.cos(angles), np.sin(angles)]) \
              * self.amplitude(*self.points, **amplitude_params) / 2
        self.prev_points = np.copy(self.points)
        self.points += dr

# %% [markdown]
# Lets create an ensemble of grains of sand.

# %%
ensemble = Sand(20, amplitude, delta=0.5)

# %% [markdown]
# We can move the sand points, and then plot

# %%
ensemble.move(n=3, m=5)

# %%
plt.plot(*ensemble.points, 'o', ms=5)
plt.grid()
plt.xlim(-1,1)
plt.ylim(-1,1)
# Out:
# (-1.0, 1.0)

# %% [markdown]
# After enough time, they should settle into position. We can see this if we choose a lot of grains of sand:

# %%
ensemble = Sand(10000, amplitude, delta=0.05)

# %% [markdown]
# This loop will move the sand 10 times, then plot

# %%
for i in range(1000):
    ensemble.move(n=1, m=3)

# %%
plt.plot(*ensemble.points, 'o', ms=2)
plt.grid()
plt.xlim(-1,1)
plt.ylim(-1,1)
# Out:
# (-1.0, 1.0)

# %% [markdown]
# Here we make an animation:
# * Every 5 frames, we move all the points
# * For the in between frames, we use linear interpolation to get the position as each grain of sand is going from its initial position to its moved position (this enables a smooth animation)

# %%
fig, ax = plt.subplots(1,1, figsize=(10,10))
ln1, = plt.plot([], [], 'o', ms=2, color='white')
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
ax.set_facecolor('black')
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)

def animate(i):
    if i%5==0:
        if i<=250:
            ensemble.move(n=3, m=5)
        elif i>250:
            ensemble.move(n=7, m=3)
    points = ensemble.prev_points + (i%5)/5 *(ensemble.points-ensemble.prev_points)
    ln1.set_data(*points)

ensemble = Sand(10000, amplitude, delta=0.075)
ani = animation.FuncAnimation(fig, animate, frames=500, interval=50)
ani.save('../images/sand.gif',writer='pillow',fps=25,dpi=200)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\lukep\Code\youtube_channel\Python Metaphysics Series\vid37.ipynb Cell 30 in <cell line: 20>()
#      <a href='vscode-notebook-cell:/c%3A/Users/lukep/Code/youtube_channel/Python%20Metaphysics%20Series/vid37.ipynb#X41sZmlsZQ%3D%3D?line=17'>18</a> ensemble = Sand(10000, amplitude, delta=0.075)
#      <a href='vscode-notebook-cell:/c%3A/Users/lukep/Code/youtube_channel/Python%20Metaphysics%20Series/vid37.ipynb#X41sZmlsZQ%3D%3D?line=18'>19</a> ani = animation.FuncAnimation(fig, animate, frames=500, interval=50)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/lukep/Code/youtube_channel/Python%20Metaphysics%20Series/vid37.ipynb#X41sZmlsZQ%3D%3D?line=19'>20</a> ani.save('../images/sand.gif',writer='pillow',fps=25,dpi=200)
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\animation.py:1095, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1093         progress_callback(frame_number, total_frames)
#    1094         frame_number += 1
# -> 1095 writer.grab_frame(**savefig_kwargs)
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\animation.py:508, in PillowWriter.grab_frame(self, **savefig_kwargs)
#     506 def grab_frame(self, **savefig_kwargs):
#     507     buf = BytesIO()
# --> 508     self.fig.savefig(
#     509         buf, **{**savefig_kwargs, "format": "rgba", "dpi": self.dpi})
#     510     self._frames.append(Image.frombuffer(
#     511         "RGBA", self.frame_size, buf.getbuffer(), "raw", "RGBA", 0, 1))
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:483, in FigureCanvasAgg.print_raw(self, filename_or_obj, *args)
#     480 @_check_savefig_extra_args
#     481 @_api.delete_parameter("3.5", "args")
#     482 def print_raw(self, filename_or_obj, *args):
# --> 483     FigureCanvasAgg.draw(self)
#     484     renderer = self.get_renderer()
#     485     with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\spines.py:290, in Spine.draw(self, renderer)
#     287 @allow_rasterization
#     288 def draw(self, renderer):
#     289     self._adjust_location()
# --> 290     ret = super().draw(renderer)
#     291     self.stale = False
#     292     return ret
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\patches.py:611, in Patch.draw(self, renderer)
#     609 transform = self.get_transform()
#     610 tpath = transform.transform_path_non_affine(path)
# --> 611 affine = transform.get_affine()
#     612 draw_path(tpath, affine,
#     613           # Work around a bug in the PDF and SVG renderers, which
#     614           # do not draw the hatches if the facecolor is fully
#     615           # transparent, but do if it is None.
#     616           self._facecolor if self._facecolor[3] else None)
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\transforms.py:2261, in BlendedGenericTransform.get_affine(self)
#    2258 def get_affine(self):
#    2259     # docstring inherited
#    2260     if self._invalid or self._affine is None:
# -> 2261         if self._x == self._y:
#    2262             self._affine = self._x.get_affine()
#    2263         else:
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\transforms.py:1793, in AffineBase.__eq__(self, other)
#    1791 def __eq__(self, other):
#    1792     if getattr(other, "is_affine", False) and hasattr(other, "get_matrix"):
# -> 1793         return np.all(self.get_matrix() == other.get_matrix())
#    1794     return NotImplemented
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\transforms.py:1583, in Transform.get_matrix(self)
#    1581 def get_matrix(self):
#    1582     """Get the matrix for the affine part of this transform."""
# -> 1583     return self.get_affine().get_matrix()
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# File c:\Users\lukep\anaconda3\lib\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
